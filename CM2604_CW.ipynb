# %%
import pandas as pd

# %%
train_path = r'C:\Users\nisal\Machine Learning\adult\adult.test'
test_path = r'C:\Users\nisal\Machine Learning\adult\adult.data'

# %%
# view test data
df1 = pd.read_csv(test_path)
df1.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
# view train data
df2 = pd.read_csv(train_path)
df2.head()
# Out:
#                                                                                                                                 |1x3 Cross validator
# 25  Private   226802  11th         7   Never-married       Machine-op-inspct  Own-child  Black  Male   0    0 40  United-States               <=50K.
# 38  Private   89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband    White  Male   0    0 50  United-States               <=50K.
# 28  Local-gov 336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband    White  Male   0    0 40  United-States                >50K.
# 44  Private   160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband    Black  Male   7688 0 40  United-States                >50K.
# 18  ?         103497  Some-college 10  Never-married       ?                  Own-child  White  Female 0    0 30  United-States               <=50K.

# %%
columns = [
    "age", "workclass", "final-weight", "education", "education-num", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", 
    "capital-loss", "hours-per-week", "native-country", "income"]

# %%
# assigning columns
# remove white space after every ','
# show '?' values as 'NaN'
train_df = pd.read_csv(test_path, names=columns, sep=',\s', na_values=["?"],engine='python')
train_df.head()
# Out:
#    age         workclass  final-weight  education  education-num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# assigning columns
# remove white space after every ','
# show '?' values as 'NaN'
# remove first row 
test_df = pd.read_csv(train_path, names=columns, sep=',\s', na_values=["?"], skiprows=1,engine='python')
test_df.head()
# Out:
#    age  workclass  final-weight     education  education-num  \
# 0   25    Private        226802          11th              7
# 1   38    Private         89814       HS-grad              9
# 2   28  Local-gov        336951    Assoc-acdm             12
# 3   44    Private        160323  Some-college             10
# 4   18        NaN        103497  Some-college             10
#
#        marital-status         occupation relationship   race     sex  \
# 0       Never-married  Machine-op-inspct    Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2  Married-civ-spouse    Protective-serv      Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4       Never-married                NaN    Own-child  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  income
# 0             0             0              40  United-States  <=50K.
# 1             0             0              50  United-States  <=50K.
# 2             0             0              40  United-States   >50K.
# 3          7688             0              40  United-States   >50K.
# 4             0             0              30  United-States  <=50K.

# %%
# check data types before merge
print("TRAIN DATA TYPES")
print(train_df.dtypes)
print("------------------------")
print("TEST DATA TYPES")
print(test_df.dtypes)
# Out:
# TRAIN DATA TYPES
# age                int64
# workclass         object
# final-weight       int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object
# ------------------------
# TEST DATA TYPES
# age                int64
# workclass         object
# final-weight       int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
# train data types and test data types equal
# merge two datasets
merged_df = pd.concat([train_df, test_df])
merged_df.head()
# Out:
#    age         workclass  final-weight  education  education-num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48842 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   final-weight    48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      46033 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 6.0+ MB

# %%
from sklearn.utils import shuffle

# %%
# shuffle merged data for prevents any bias and ensure data is randomized
shuffled_df = shuffle(merged_df)
shuffled_df.head()
# Out:
#        age         workclass  final-weight     education  education-num  \
# 10723   19           Private         41400       HS-grad              9
# 9100    24           Private        165107     Bachelors             13
# 19274   45         Local-gov        144940       Masters             14
# 10281   24           Private        339602  Some-college             10
# 16862   35  Self-emp-not-inc        193260       Masters             14
#
#            marital-status         occupation   relationship  \
# 10723       Never-married  Handlers-cleaners      Own-child
# 9100        Never-married    Exec-managerial      Own-child
# 19274            Divorced     Prof-specialty      Unmarried
# 10281       Never-married       Adm-clerical  Not-in-family
# 16862  Married-civ-spouse              Sales        Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 10723               White    Male             0             0              30
# 9100                White  Female             0             0              40
# 19274               Black  Female             0             0              40
# 10281               White  Female             0             0              40
# 16862  Asian-Pac-Islander    Male             0             0              40
#
#       native-country  income
# 10723  United-States   <=50K
# 9100   United-States  <=50K.
# 19274  United-States   <=50K
# 10281  United-States  <=50K.
# 16862            NaN    >50K

# %%
# save shuffled data as new csv
dir = r'C:\Users\nisal\Machine Learning\census_income_datset.csv'
# without index as a separate column
shuffled_df.to_csv(dir, index=False)
print('Saved at',dir)
# Out:
# Saved at C:\Users\nisal\Machine Learning\census_income_datset.csv

# %%
census_df = pd.read_csv(dir)
census_df.head()
# Out:
#    age         workclass  final-weight     education  education-num  \
# 0   19           Private         41400       HS-grad              9
# 1   24           Private        165107     Bachelors             13
# 2   45         Local-gov        144940       Masters             14
# 3   24           Private        339602  Some-college             10
# 4   35  Self-emp-not-inc        193260       Masters             14
#
#        marital-status         occupation   relationship                race  \
# 0       Never-married  Handlers-cleaners      Own-child               White
# 1       Never-married    Exec-managerial      Own-child               White
# 2            Divorced     Prof-specialty      Unmarried               Black
# 3       Never-married       Adm-clerical  Not-in-family               White
# 4  Married-civ-spouse              Sales        Husband  Asian-Pac-Islander
#
#       sex  capital-gain  capital-loss  hours-per-week native-country  income
# 0    Male             0             0              30  United-States   <=50K
# 1  Female             0             0              40  United-States  <=50K.
# 2  Female             0             0              40  United-States   <=50K
# 3  Female             0             0              40  United-States  <=50K.
# 4    Male             0             0              40            NaN    >50K

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   final-weight    48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      46033 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
census_df.nunique()
# Out:
# age                  74
# workclass             8
# final-weight      28523
# education            16
# education-num        16
# marital-status        7
# occupation           14
# relationship          6
# race                  5
# sex                   2
# capital-gain        123
# capital-loss         99
# hours-per-week       96
# native-country       41
# income                4
# dtype: int64

# %%
# check unique values in each columns
for column in census_df:
    print(column)
    print(census_df[column].unique())
    print('\n')
# Out:
# age
# [19 24 45 35 38 39 26 30 43 28 40 41 62 49 22 46 21 56 31 42 36 50 33 48
#  23 25 58 17 59 71 52 29 57 20 18 81 32 54 64 53 51 69 37 27 44 65 34 63
#  61 55 60 70 75 67 47 66 72 68 77 76 73 83 87 90 74 86 79 88 80 78 82 84
#  89 85]
#
#
# workclass
# ['Private' 'Local-gov' 'Self-emp-not-inc' 'State-gov' nan 'Self-emp-inc'
#  'Federal-gov' 'Never-worked' 'Without-pay']
#
#
# final-weight
# [ 41400 165107 144940 ... 119253 323120 226918]
#
#
# education
# ['HS-grad' 'Bachelors' 'Masters' 'Some-college' 'Assoc-acdm' '10th' '11th'
#  '7th-8th' 'Prof-school' 'Doctorate' '9th' '5th-6th' '12th' 'Assoc-voc'
#  '1st-4th' 'Preschool']
#
#
# education-num
# [ 9 13 14 10 12  6  7  4 15 16  5  3  8 11  2  1]
#
#
# marital-status
# ['Never-married' 'Divorced' 'Married-civ-spouse' 'Married-spouse-absent'
#  'Widowed' 'Separated' 'Married-AF-spouse']
#
#
# occupation
# ['Handlers-cleaners' 'Exec-managerial' 'Prof-specialty' 'Adm-clerical'
#  'Sales' 'Tech-support' 'Transport-moving' 'Farming-fishing'
#  'Protective-serv' 'Machine-op-inspct' 'Craft-repair' 'Other-service' nan
#  'Priv-house-serv' 'Armed-Forces']
#
#
# relationship
# ['Own-child' 'Unmarried' 'Not-in-family' 'Husband' 'Wife' 'Other-relative']
#
#
# race
# ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
#
#
# sex
# ['Male' 'Female']
#
#
# capital-gain
# [    0  7298 99999  2885  5178  3103  3325  4650  8614  2977  2635  3418
#   4101  7688 15024  2407  6849  2174  4386  7896  2829   594  3273  3908
#   4064  2414  3411  1831 15020 14344 27828  2202 13550 14084  3674  2597
#   3137  4787 11678  2964 10605  1173  2290  5013  9562  6497  4416  1055
#  34095  9386  3471  4934  3432  2354  2036  6360  4865  1409  1848   114
#    991 20051  2176  2907  3464  2009  1471  7443 10520  7430  2580  6418
#   6767  2653  4508  4931  5455  2961  2105   914  3781  1506  1151  2538
#   5721  6612  1455  1424 25124  3942 41310  1086 18481 15831  1797 25236
#   2346  7262 10566  2993  2463  7978  3456  3887  3818  6097  6723  2050
#   2329  4687  6514  2228  5556   401  2062  5060  1264  1111  2936  2387
#   1639  1731 22040]
#
#
# capital-loss
# [   0 1902 1741 1602 1848 1721 1887 1408 1485 1672 2080  974 1977 2339
#  1258 2258 1974 1669 2205 2057 1579 2001 1980 2377 1651 2002 2472 1564
#  1411 2457 2415 1740 2246 1825 1092 1876  213 1510 1719 1590 1668 2444
#  1762 1628 2824  653 2129 2179 2051 2149 1429 1340 1594 2392  625 2267
#  1504 2754 1816 1726 3770 1617 2547 2559 1380 1573 1648  880 1755 3175
#  2206 2042 2603  810 1735  323 1844  419 2489 3004 1944 2238 2231 1138
#  2163 2174  155 2282 3683 2467 3900 2352 1870 1911 1421 2465 4356 2201
#  1539]
#
#
# hours-per-week
# [30 40 35 50 45 99 53 60 38 32 48 20 41 21 47 80 16 34 37 15 44 25 10 43
#  52 42 33 65 24  4 27 63 54  8 13 58 84  6 55 62 72 12 18 36 28  1 46 49
#  23 39 56  5 22 70 26 57 17 11  3 75 90 85  2 77 31 66 29 96 73 14 91 76
#  61  7 78 64 68 19 98 59 51  9 86 88 81 67 74 92 97 89 79 87 95 94 82 69]
#
#
# native-country
# ['United-States' nan 'Dominican-Republic' 'Mexico' 'El-Salvador'
#  'Portugal' 'Ecuador' 'Canada' 'England' 'Germany' 'Thailand' 'Taiwan'
#  'Guatemala' 'India' 'South' 'Philippines' 'Ireland' 'Puerto-Rico' 'Japan'
#  'Greece' 'Cambodia' 'Scotland' 'China' 'Cuba' 'Columbia' 'Iran'
#  'Yugoslavia' 'Outlying-US(Guam-USVI-etc)' 'France' 'Holand-Netherlands'
#  'Peru' 'Jamaica' 'Honduras' 'Haiti' 'Vietnam' 'Hong' 'Trinadad&Tobago'
#  'Laos' 'Nicaragua' 'Italy' 'Poland' 'Hungary']
#
#
# income
# ['<=50K' '<=50K.' '>50K' '>50K.']

# %%
# replace values in 'income' column
census_df['income'] = census_df['income'].replace({'<=50K.': '<=50K', '>50K.': '>50K'})

# %%
# check updated unique values in each columns
for column in census_df:
    print(column)
    print(census_df[column].unique())
    print('\n')
# Out:
# age
# [19 24 45 35 38 39 26 30 43 28 40 41 62 49 22 46 21 56 31 42 36 50 33 48
#  23 25 58 17 59 71 52 29 57 20 18 81 32 54 64 53 51 69 37 27 44 65 34 63
#  61 55 60 70 75 67 47 66 72 68 77 76 73 83 87 90 74 86 79 88 80 78 82 84
#  89 85]
#
#
# workclass
# ['Private' 'Local-gov' 'Self-emp-not-inc' 'State-gov' nan 'Self-emp-inc'
#  'Federal-gov' 'Never-worked' 'Without-pay']
#
#
# final-weight
# [ 41400 165107 144940 ... 119253 323120 226918]
#
#
# education
# ['HS-grad' 'Bachelors' 'Masters' 'Some-college' 'Assoc-acdm' '10th' '11th'
#  '7th-8th' 'Prof-school' 'Doctorate' '9th' '5th-6th' '12th' 'Assoc-voc'
#  '1st-4th' 'Preschool']
#
#
# education-num
# [ 9 13 14 10 12  6  7  4 15 16  5  3  8 11  2  1]
#
#
# marital-status
# ['Never-married' 'Divorced' 'Married-civ-spouse' 'Married-spouse-absent'
#  'Widowed' 'Separated' 'Married-AF-spouse']
#
#
# occupation
# ['Handlers-cleaners' 'Exec-managerial' 'Prof-specialty' 'Adm-clerical'
#  'Sales' 'Tech-support' 'Transport-moving' 'Farming-fishing'
#  'Protective-serv' 'Machine-op-inspct' 'Craft-repair' 'Other-service' nan
#  'Priv-house-serv' 'Armed-Forces']
#
#
# relationship
# ['Own-child' 'Unmarried' 'Not-in-family' 'Husband' 'Wife' 'Other-relative']
#
#
# race
# ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
#
#
# sex
# ['Male' 'Female']
#
#
# capital-gain
# [    0  7298 99999  2885  5178  3103  3325  4650  8614  2977  2635  3418
#   4101  7688 15024  2407  6849  2174  4386  7896  2829   594  3273  3908
#   4064  2414  3411  1831 15020 14344 27828  2202 13550 14084  3674  2597
#   3137  4787 11678  2964 10605  1173  2290  5013  9562  6497  4416  1055
#  34095  9386  3471  4934  3432  2354  2036  6360  4865  1409  1848   114
#    991 20051  2176  2907  3464  2009  1471  7443 10520  7430  2580  6418
#   6767  2653  4508  4931  5455  2961  2105   914  3781  1506  1151  2538
#   5721  6612  1455  1424 25124  3942 41310  1086 18481 15831  1797 25236
#   2346  7262 10566  2993  2463  7978  3456  3887  3818  6097  6723  2050
#   2329  4687  6514  2228  5556   401  2062  5060  1264  1111  2936  2387
#   1639  1731 22040]
#
#
# capital-loss
# [   0 1902 1741 1602 1848 1721 1887 1408 1485 1672 2080  974 1977 2339
#  1258 2258 1974 1669 2205 2057 1579 2001 1980 2377 1651 2002 2472 1564
#  1411 2457 2415 1740 2246 1825 1092 1876  213 1510 1719 1590 1668 2444
#  1762 1628 2824  653 2129 2179 2051 2149 1429 1340 1594 2392  625 2267
#  1504 2754 1816 1726 3770 1617 2547 2559 1380 1573 1648  880 1755 3175
#  2206 2042 2603  810 1735  323 1844  419 2489 3004 1944 2238 2231 1138
#  2163 2174  155 2282 3683 2467 3900 2352 1870 1911 1421 2465 4356 2201
#  1539]
#
#
# hours-per-week
# [30 40 35 50 45 99 53 60 38 32 48 20 41 21 47 80 16 34 37 15 44 25 10 43
#  52 42 33 65 24  4 27 63 54  8 13 58 84  6 55 62 72 12 18 36 28  1 46 49
#  23 39 56  5 22 70 26 57 17 11  3 75 90 85  2 77 31 66 29 96 73 14 91 76
#  61  7 78 64 68 19 98 59 51  9 86 88 81 67 74 92 97 89 79 87 95 94 82 69]
#
#
# native-country
# ['United-States' nan 'Dominican-Republic' 'Mexico' 'El-Salvador'
#  'Portugal' 'Ecuador' 'Canada' 'England' 'Germany' 'Thailand' 'Taiwan'
#  'Guatemala' 'India' 'South' 'Philippines' 'Ireland' 'Puerto-Rico' 'Japan'
#  'Greece' 'Cambodia' 'Scotland' 'China' 'Cuba' 'Columbia' 'Iran'
#  'Yugoslavia' 'Outlying-US(Guam-USVI-etc)' 'France' 'Holand-Netherlands'
#  'Peru' 'Jamaica' 'Honduras' 'Haiti' 'Vietnam' 'Hong' 'Trinadad&Tobago'
#  'Laos' 'Nicaragua' 'Italy' 'Poland' 'Hungary']
#
#
# income
# ['<=50K' '>50K']

# %%
# check null(nun) values
nun_values = census_df.isnull().sum()
total_nun_values = nun_values.sum()
print(nun_values)
print("total null(nun) values :",total_nun_values)
# Out:
# age                  0
# workclass         2799
# final-weight         0
# education            0
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# income               0
# dtype: int64
# total null(nun) values : 6465

# %%
# nan values replace from forward filling
census_df.fillna(method = 'ffill', inplace = True)

# %%
# check null(nun) values again
nun_values = census_df.isnull().sum()
total_nun_values = nun_values.sum()
print(nun_values)
print("total null(nun) values :",total_nun_values)
# Out:
# age               0
# workclass         0
# final-weight      0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64
# total null(nun) values : 0

# %%
# check how many duplicate rows
duplicate_rows = census_df.duplicated().sum()
print("Number of duplicate rows :", duplicate_rows)
# Out:
# Number of duplicate rows : 47

# %%
# keep means drop duplicates without first occurrence.
census_df.drop_duplicates(keep='first', inplace=True)

# %%
# check how many duplicate rows again
duplicate_rows = census_df.duplicated().sum()
print("Number of duplicate rows :", duplicate_rows)
# Out:
# Number of duplicate rows : 0

# %%
census_df.hist(figsize=(20, 20), edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'final-weight'}>],
#        [<Axes: title={'center': 'education-num'}>,
#         <Axes: title={'center': 'capital-gain'}>],
#        [<Axes: title={'center': 'capital-loss'}>,
#         <Axes: title={'center': 'hours-per-week'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numerical_features = ['age','education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

def detect_outliers_iqr(data, columns):
    outliers = {}
    for col in columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outlier_indices = data[(data[col] < lower_bound) | (data[col] > upper_bound)].index
        outliers[col] = outlier_indices
    return outliers


# Detect outliers
outlier_indices = detect_outliers_iqr(census_df, numerical_features)

# Visualize outliers using box plots
for col, indices in outlier_indices.items():
    if len(indices) > 0:
        plt.figure(figsize=(8, 6))
        sns.boxplot(x=census_df[col])
        plt.title("box plot - '{}' with outliers".format(col))
        plt.show()

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48795 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48795 non-null  int64
#  1   workclass       48795 non-null  object
#  2   final-weight    48795 non-null  int64
#  3   education       48795 non-null  object
#  4   education-num   48795 non-null  int64
#  5   marital-status  48795 non-null  object
#  6   occupation      48795 non-null  object
#  7   relationship    48795 non-null  object
#  8   race            48795 non-null  object
#  9   sex             48795 non-null  object
#  10  capital-gain    48795 non-null  int64
#  11  capital-loss    48795 non-null  int64
#  12  hours-per-week  48795 non-null  int64
#  13  native-country  48795 non-null  object
#  14  income          48795 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 6.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
conv_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'income']

# initialize LabelEncoder
label_encoder = LabelEncoder()

# convert
for column in conv_columns:
    census_df[column] = label_encoder.fit_transform(census_df[column])

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48795 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48795 non-null  int64
#  1   workclass       48795 non-null  int32
#  2   final-weight    48795 non-null  int64
#  3   education       48795 non-null  int32
#  4   education-num   48795 non-null  int64
#  5   marital-status  48795 non-null  int32
#  6   occupation      48795 non-null  int32
#  7   relationship    48795 non-null  int32
#  8   race            48795 non-null  int32
#  9   sex             48795 non-null  int32
#  10  capital-gain    48795 non-null  int64
#  11  capital-loss    48795 non-null  int64
#  12  hours-per-week  48795 non-null  int64
#  13  native-country  48795 non-null  int32
#  14  income          48795 non-null  int32
# dtypes: int32(9), int64(6)
# memory usage: 4.3 MB

# %%
# calculate the correlation matrix
correlation_matrix = census_df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
# correlation with the target variable
correlation_with_income = correlation_matrix['income'].sort_values(ascending=False)
correlation_with_income
# Out:
# income            1.000000
# education-num     0.332784
# age               0.230187
# hours-per-week    0.227651
# capital-gain      0.223052
# sex               0.214611
# capital-loss      0.147551
# education         0.080073
# race              0.070970
# occupation        0.046104
# native-country    0.019471
# workclass        -0.001433
# final-weight     -0.006302
# marital-status   -0.198889
# relationship     -0.253178
# Name: income, dtype: float64

# %%
# List of columns to remove
columns_to_remove = ['final-weight']

# drop the columns
census_df.drop(columns=columns_to_remove, inplace=True)

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48795 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48795 non-null  int64
#  1   workclass       48795 non-null  int32
#  2   education       48795 non-null  int32
#  3   education-num   48795 non-null  int64
#  4   marital-status  48795 non-null  int32
#  5   occupation      48795 non-null  int32
#  6   relationship    48795 non-null  int32
#  7   race            48795 non-null  int32
#  8   sex             48795 non-null  int32
#  9   capital-gain    48795 non-null  int64
#  10  capital-loss    48795 non-null  int64
#  11  hours-per-week  48795 non-null  int64
#  12  native-country  48795 non-null  int32
#  13  income          48795 non-null  int32
# dtypes: int32(9), int64(5)
# memory usage: 3.9 MB

# %%
# check data imbalance
income_counts = census_df['income'].value_counts()

# Plot the income distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=income_counts.index, y=income_counts.values)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Count')
plt.show()

# %%
income_counts = census_df['income'].value_counts()
income_counts
# Out:
# income
# 0    37114
# 1    11681
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# Separate features and target variable
X = census_df.drop('income', axis=1)
y = census_df['income']

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Perform oversampling
X_resampled, y_resampled = smote.fit_resample(X, y)

# Create a new DataFrame with oversampled data
census_df = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='income')], axis=1)

# Check the class distribution in the oversampled dataset
print(census_df['income'].value_counts())
# Out:
# income
# 0    37114
# 1    37114
# Name: count, dtype: int64

# %%
# check data balance
income_counts = census_df['income'].value_counts()

# Plot the income distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=income_counts.index, y=income_counts.values)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Count')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# Define features (X) and target variable (y)
X = census_df.drop('income', axis=1)
y = census_df['income']

# Encode categorical variables
X_encoded = pd.get_dummies(X)

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Naive Bayes model
nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)
nb_predictions = nb_classifier.predict(X_test)

# %%
# Naive Bayes evaluation
nb_accuracy = accuracy_score(y_test, nb_predictions)*100
print("Naive Bayes Classifier Accuracy:", nb_accuracy.round(2), "%")
print("\n")
print("Naive Bayes Classifier Report:")
print(classification_report(y_test, nb_predictions))
# Out:
# Naive Bayes Classifier Accuracy: 69.38 %
#
#
# Naive Bayes Classifier Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.93      0.75      7427
#            1       0.87      0.46      0.60      7419
#
#     accuracy                           0.69     14846
#    macro avg       0.75      0.69      0.68     14846
# weighted avg       0.75      0.69      0.68     14846

# %%
# Plot confusion matrix for Naive Bayes
nb_conf_matrix = confusion_matrix(y_test, nb_predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(nb_conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Naive Bayes Classifier')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Random Forest model
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
rf_predictions = rf_classifier.predict(X_test)

# %%
# Random Forest evaluation
rf_accuracy = accuracy_score(y_test, rf_predictions)*100
print("Random Forest Classifier Accuracy:", rf_accuracy.round(2), "%")
print("\n")
print("Random Forest Classifier Report:")
print(classification_report(y_test, rf_predictions))
# Out:
# Random Forest Classifier Accuracy: 88.95 %
#
#
# Random Forest Classifier Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89      7427
#            1       0.88      0.91      0.89      7419
#
#     accuracy                           0.89     14846
#    macro avg       0.89      0.89      0.89     14846
# weighted avg       0.89      0.89      0.89     14846

# %%
# Plot confusion matrix for Random Forest
rf_conf_matrix = confusion_matrix(y_test, rf_predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(rf_conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Random Forest Classifier')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# save shuffled data as new csv
dir = r'C:\Users\nisal\Machine Learning\census_income_datset.csv'
# without index as a separate column
shuffled_df.to_csv(dir, index=False)
print('Saved at',dir)
# Out:
# Saved at C:\Users\nisal\Machine Learning\census_income_datset.csv
